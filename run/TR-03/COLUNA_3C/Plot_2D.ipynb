# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
from scipy.io import arff

# %%
base = arff.loadarff("/home/davi/PycharmProjects/M-learn/mlfwk/datasets/column_3C_weka.arff")
base = pd.DataFrame(base[0])

# %%
base.head()
# Out:
#    pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 0         63.027817    22.552586              39.609117     40.475232
# 1         39.056951    10.060991              25.015378     28.995960
# 2         68.832021    22.218482              50.092194     46.613539
# 3         69.297008    24.652878              44.311238     44.644130
# 4         49.712859     9.652075              28.317406     40.060784
#
#    pelvic_radius  degree_spondylolisthesis      class
# 0      98.672917                 -0.254400  b'Hernia'
# 1     114.405425                  4.564259  b'Hernia'
# 2     105.985135                 -3.530317  b'Hernia'
# 3     101.868495                 11.211523  b'Hernia'
# 4     108.168725                  7.918501  b'Hernia'

# %%
sns.scatterplot(data=base, x="pelvic_incidence", y="pelvic_tilt", hue="class", legend='brief')
plt.legend()
plt.savefig('pelvic_incidence_x_pelvic_tilt_3C.png')
plt.show()
