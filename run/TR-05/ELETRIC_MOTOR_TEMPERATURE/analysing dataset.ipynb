# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd

# %% [markdown]
# <h1>1. Introdução</h1>

# %% [markdown]
# <h2>1.1 Leitura dos dados</h2>

# %%
n_read_rows = None
df = pd.read_csv('/home/davi/PycharmProjects/M-learn/mlfwk/datasets/measures_v2.csv', delimiter=',', nrows = n_read_rows)
df.dataframeName = 'pmsm_temperature_data.csv'
nRow, nCol = df.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 1330816 rows and 13 columns

# %%
df.head()
# Out:
#         u_q    coolant  stator_winding       u_d  stator_tooth  motor_speed  \
# 0 -0.450682  18.805172       19.086670 -0.350055     18.293219     0.002866
# 1 -0.325737  18.818571       19.092390 -0.305803     18.294807     0.000257
# 2 -0.440864  18.828770       19.089380 -0.372503     18.294094     0.002355
# 3 -0.327026  18.835567       19.083031 -0.316199     18.292542     0.006105
# 4 -0.471150  18.857033       19.082525 -0.332272     18.291428     0.003133
#
#         i_d       i_q         pm  stator_yoke    ambient    torque  profile_id
# 0  0.004419  0.000328  24.554214    18.316547  19.850691  0.187101          17
# 1  0.000606 -0.000785  24.538078    18.314955  19.850672  0.245417          17
# 2  0.001290  0.000386  24.544693    18.326307  19.850657  0.176615          17
# 3  0.000026  0.002046  24.554018    18.330833  19.850647  0.238303          17
# 4 -0.064317  0.037184  24.565397    18.326662  19.850639  0.208197          17

# %%
target_features = ['stator_yoke', 'stator_winding', 'stator_tooth', 'pm']

# %%
df.describe()
# Out:
#                u_q      coolant  stator_winding          u_d  stator_tooth  \
# count  1000.000000  1000.000000     1000.000000  1000.000000   1000.000000
# mean     87.507358    19.073372       50.918548   -90.450780     39.933239
# std      14.804269     0.180096       14.180182    15.866250     10.271482
# min      -0.974433    18.717588       19.049341   -94.935555     18.276365
# 25%      89.326099    18.927147       42.184696   -94.097601     33.052427
# 50%      89.951389    19.082160       55.837881   -93.492088     43.182589
# 75%      90.634176    19.236844       62.928321   -92.673264     49.061152
# max      95.686531    19.383579       66.190247     0.851181     52.492031
#
#        motor_speed          i_d          i_q           pm  stator_yoke  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean   4838.654236  -136.342778    51.659946    39.023041    30.045417
# std     850.588053    24.495547     8.309924     8.052070     6.355640
# ...

# %%
df.isnull().sum()
# Out:
# u_q               0
# coolant           0
# stator_winding    0
# u_d               0
# stator_tooth      0
# motor_speed       0
# i_d               0
# i_q               0
# pm                0
# stator_yoke       0
# ambient           0
# torque            0
# profile_id        0
# dtype: int64

# %%
df.columns
# Out:
# Index(['u_q', 'coolant', 'stator_winding', 'u_d', 'stator_tooth',
#        'motor_speed', 'i_d', 'i_q', 'pm', 'stator_yoke', 'ambient', 'torque',
#        'profile_id'],
#       dtype='object')

# %% [markdown]
# <h1>2. Desenvolvimento</h1>
